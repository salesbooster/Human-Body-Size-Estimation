# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DataSet_Classification.csv')
df.head()
# Out:
#    Chest  Shoulder  Sleeve_Length  Waist  Predicted_Size
# 0   96.5     43.18           19.0   96.5               1
# 1   96.5     43.18           19.0   97.0               1
# 2   96.5     43.18           19.0   97.5               1
# 3   96.5     43.18           19.0   98.0               1
# 4   96.5     43.18           19.0   98.5               1

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(df, hue="Predicted_Size", height=3);
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue='Predicted_Size', size=5) \
.map(plt.scatter, "Chest", "Shoulder") \
.add_legend();
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
x_data = df.drop(['Predicted_Size'],axis=1)
y_data = df['Predicted_Size']
MinMaxScaler = preprocessing.MinMaxScaler()
X_data_minmax = MinMaxScaler.fit_transform(x_data)
data = pd.DataFrame(X_data_minmax,columns=['Chest', 'Shoulder', 'Sleeve_Length', 'Waist'])



MinMaxScaler.data_min_
# Out:
# array([96.5 , 43.18, 19.  , 96.5 ])

# %%
MinMaxScaler.data_max_
# Out:
# array([116.2 ,  50.5 ,  25.14, 116.2 ])

# %%
df.head()
# Out:
#    Chest  Shoulder  Sleeve_Length  Waist  Predicted_Size
# 0   96.5     43.18           19.0   96.5               1
# 1   96.5     43.18           19.0   97.0               1
# 2   96.5     43.18           19.0   97.5               1
# 3   96.5     43.18           19.0   98.0               1
# 4   96.5     43.18           19.0   98.5               1

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue='Predicted_Size', height=10) \
.map(plt.scatter, "Chest", "Shoulder") \
.add_legend();
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y_data,test_size=0.2, random_state = 1)
knn_clf=KNeighborsClassifier()
knn_clf.fit(X_train,y_train)
ypred=knn_clf.predict(X_test) 

ypred
# Out:
# array([4, 4, 4, ..., 1, 2, 3], dtype=int64)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, ypred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, ypred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,ypred)
print("Accuracy:",result2)
# Out:
# Confusion Matrix:
# [[281   0   0   0]
#  [  0 451   0   0]
#  [  0   0 186   0]
#  [  0   0   0 341]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       281
#            2       1.00      1.00      1.00       451
#            3       1.00      1.00      1.00       186
#            4       1.00      1.00      1.00       341
#
#     accuracy                           1.00      1259
#    macro avg       1.00      1.00      1.00      1259
# weighted avg       1.00      1.00      1.00      1259
#
# Accuracy: 1.0

# %%
X_test.shape
# Out:
# (1259, 4)

# %%
type(X_test)
# Out:
# pandas.core.frame.DataFrame

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1259 entries, 5560 to 3658
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Chest          1259 non-null   float64
#  1   Shoulder       1259 non-null   float64
#  2   Sleeve_Length  1259 non-null   float64
#  3   Waist          1259 non-null   float64
# dtypes: float64(4)
# memory usage: 49.2 KB

# %%
ypred=knn_clf.predict([[90,40,10,98],[0.187665,0.102290,0.095147,0.201523]]) 
ypred
# Out:
# array([4, 1], dtype=int64)

# %%
X_train.head(10)
# Out:
#          Chest  Shoulder  Sleeve_Length     Waist
# 2717  0.411168  0.303279       0.296417  0.258883
# 686   0.177665  0.109290       0.065147  0.101523
# 2990  0.436548  0.439891       0.296417  0.487310
# 1731  0.284264  0.303279       0.296417  0.360406
# 4444  0.629442  0.713115       0.586319  0.614213
# 4708  0.796954  0.863388       0.863192  0.873096
# 5003  0.822335  1.000000       0.781759  1.000000
# 2326  0.360406  0.303279       0.296417  0.385787
# 3992  0.563452  0.713115       0.407166  0.563452
# 2596  0.385787  0.439891       0.374593  0.258883

# %%
input = np.array([90,40,10,9])
input.shape
# Out:
# (4,)

# %%
X_test.shape
# Out:
# (1259, 4)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1664
# -> 1665         mgr = BlockManager(blocks, axes)
#    1666         mgr._consolidate_inplace()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     325             if block.shape[1:] != mgr_shape[1:]:
# --> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     327         if len(self.items) != tot_items:
#
# ...

# %%
input_data
